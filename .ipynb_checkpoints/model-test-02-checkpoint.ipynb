# %% [markdown]
# # Load libraries

# %%
# !pip install -Uqq fastbook

# %%
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # Set up data

# %%
# aaf_url = 'https://www.dropbox.com/s/a0lj1ddd54ns8qy/All-Age-Faces%20Dataset.zip'
# !wget $aaf_url -P 'data'

# %%
# import zipfile
# with zipfile.ZipFile('data/All-Age-Faces Dataset.zip', 'r') as zip_ref:
#     zip_ref.extractall('data/aaf/')

# %%
fnames = get_image_files('data/aaf/All-Age-Faces Dataset/aglined faces')

# %%
dblock = DataBlock()

# %%
dsets = dblock.datasets(fnames)

# %%
def label_func(fname):
    return int(fname.name[-6:-4])

# %%
dblock = DataBlock( blocks = (ImageBlock, RegressionBlock), 
                    get_items = get_image_files,
                    get_y     = label_func,
                    splitter  = RandomSplitter(),
                    item_tfms = Resize(224))

dsets = dblock.datasets('data/aaf/All-Age-Faces Dataset/aglined faces')
dsets.train[0]
# Out:
# (PILImage mode=RGB size=301x371, tensor(24.))

# %%
dls = dblock.dataloaders(Path('data/aaf/All-Age-Faces Dataset/aglined faces'))

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
learn = cnn_learner(dls, resnet34, metrics=rmse)

# %%
learn.fine_tune(4)
learn.export()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>_rmse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1033.873413</td>
#       <td>626.019043</td>
#       <td>25.020370</td>
#       <td>02:36</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>_rmse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>328.631073</td>
#       <td>179.288528</td>
#       <td>13.389867</td>
#       <td>03:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>116.017525</td>
#       <td>80.860275</td>
#       <td>8.992233</td>
#       <td>03:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>81.307152</td>
#       <td>65.590607</td>
#       <td>8.098804</td>
#       <td>03:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>61.790997</td>
#       <td>61.855381</td>
#       <td>7.864820</td>
#       <td>03:40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Inference

# %%
learn_inf = load_learner('export.pkl')

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
# btn_upload = SimpleNamespace(data = ['simu_liu.jpg'])

# %%
btn_upload.data
# Out:
# [b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\x02@ICC_PROFILE\x00\x01\x01\x00\x00\x020ADBE\x02\x10\x00\x00mntrRGB XYZ \x07\xcf\x00\x06\x00\x03\x00\x00\x00\x00\x00\x00acspAPPL\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-ADBE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ncprt\x00\x00\x00\xfc\x00\x00\x002desc\x00\x00\x010\x00\x00\x00kwtpt\x00\x00\x01\x9c\x00\x00\x00\x14bkpt\x00\x00\x01\xb0\x00\x00\x00\x14rTRC\x00\x00\x01\xc4\x00\x00\x00\x0egTRC\x00\x00\x01\xd4\x00\x00\x00\x0ebTRC\x00\x00\x01\xe4\x00\x00\x00\x0erXYZ\x00\x00\x01\xf4\x00\x00\x00\x14gXYZ\x00\x00\x02\x08\x00\x00\x00\x14bXYZ\x00\x00\x02\x1c\x00\x00\x00\x14text\x00\x00\x00\x00Copyright 1999 Adobe Systems Incorporated\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x11Adobe RGB (1998)XYZ \x00\x00\x00\x00\x00\x00\xf3Q\x00\x01\x00\x00\x00\x01\x16\xccXYZ \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x01\x023\x00\x00XYZ \x00\x00\x00\x00\x00\x00\x9c\x18\x00\x00O\xa5\x00\x00\x04\xfcXYZ \x00\x00\x00\x00\x00\x004\x8d\x00\x00\xa0,\x00\x00\x0f\x95XYZ \x00\x00\x00\x00\x00\x00&1\x00\x00\x10/\x00\x00\xbe\x9c\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc2\x00\x11\x08\x04\xb0\x04\xb0\x03\x01"P\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05>3;\xf81\x9a\t&\x9b\x96ST\x0cp\x9b\x15&$c\xd1\x91\xc5\xc5\xe8p\x9ev\x1d\xd5g7V\xfdS\\\xdb\xefmF\xb5J\xa9\xb1QBe\t\x8c\x1b\xb2i\xd0\xa9\xb0\xa4\xc0\x00\x92A$1\x00\x08h\x02\xe2\xab\xbb\xab\x97\xaa\xe7\xa3L\xf5f\x98\xd2KdS%M\x82`\x00(\x00\x00.N\xceS\xc9\xe7\xe9\xe3\x96\xc8VQ\x01J@B\x00\x00\x00\x10\xacL\x04\xd0\x06!\x82\x18\xa8md\xb6gwR\xfd@\x17\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x96~\x03\x1bys!*\x1a\xa4\x81\xd4Q\xa5M\r\xaa\x1a`Q\xa1\x11\xd8\x8f3\x93\xd9\xe7O&\xbd\x02\xce^\x8d\xb6\x9a\xe7;\x14\xd7\x1a\xdb6\x860l\x06\xe8N\xa8\x9a\xaa&\x86\x0c\x00H\x12\x90H\x00\x10hP\x00\x00Zgk\xdd\xd5\xcb\xd7\xaco\xb6{3M\x90\x00\x00\x00\n\x00\x00\x00\x00\x00r\xf5r\x9e_\x9f\xe9ykIJQ,mP\x95!\x02\x1a\x1044\xc4)R\xd9u4\x03k.\xda\xc5S\x89\xa6\xd1Sg\xd1\x01r\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xb8\xf3\xf9\xf64\xe4P\xae\tRI\x8a%\xad\xd6zY\xa5E\x94\xd5\x05\x1a\x07B\xe9\x07\xd2\xec\xe1\xc7\xd1\xc98\'\xb34\xc3Z\xd2k9\xe8\xc9\xae\x0c\xf6\xcahe*\xa7B\xa7D\xdbbc\x00@\x81I\x12$\xd0\x80\x01\x03\x10\x00(\x00\\h\x9d\xbd\x9c}\x9a\xcfF\xd8\xec\xce\x80@\x00\x00\x00(\x00\x00\x00\x00\x01\xcf\xd1\x82y~O\xaf\xe4J\x90\xe8\xa4\xc6\xc0\x13BM\x08\x010h\x1bY\xa7i5V\xb1V\xe2KI%\x02`\x94\xe6\xcf\xa0\x02\xc0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x034\xaf\'\x0f!\x9a\xc4\x85pJ\x89%\x12QO6kyif\xb7\x16]\xce\x83\xda:\r:\xb3\xeb\xab\xad)9\xb2\xec\xc592\x ...

# %%
img = PILImage.create(btn_upload.data[-1])
img
# Out:
# PILImage mode=RGB size=1200x1200

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred = learn_inf.predict(img)

# %%
age = pred[0][0]

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred[0][0]:.01f}'
lbl_pred
# Out:
# Label(value='Prediction: 34.0')

# %%
#hide_output
btn_run = widgets.Button(description='Predict age')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred[0][0]:.01f}'

btn_run.on_click(on_click_classify)

# %%
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Upload your face!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
