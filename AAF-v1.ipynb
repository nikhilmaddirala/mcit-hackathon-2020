# --2020-08-29 00:36:26--  https://ucf14039ccc5b9ada4905f2878d8.dl.dropboxusercontent.com/cd/0/inline2/A-VeC_SkxGNvSgs_2MhtDbNLyhdqa3zIG7o_JnV-6cfFOtvxv3FiLxug98Vfc_HUKiTgF2fe-dUGUY_PeIMTjbWxuRcMLGuXBtzOu8w9A6ViClx1bWPBdZpxfxf9ZXhn8rgdm9Uh84ykk13uKshISVN7wRKcGPBakaW_GHXCP5WOh9aM6AIMizLtyxQJlDq4jrd80e1xNga_zvIheVjupzoykD4S14s2zW73M5vcUYRPAmL-yDjrflJ0TbsVErI9WV_cfuHkj881P492cmxTeZstHIq1uRIXCgn-qRUDhc63zc4wVcYHbu15tagOs6gDrogBEYb907DhuxcjCF6Bf-OH/file
# Reusing existing connection to ucf14039ccc5b9ada4905f2878d8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 365164027 (348M) [application/zip]
# Saving to: ‘data/All-Age-Faces Dataset.zip’
#
# All-Age-Faces Datas 100%[===================>] 348.25M  68.2MB/s    in 5.2s
#
# 2020-08-29 00:36:34 (66.7 MB/s) - ‘data/All-Age-Faces Dataset.zip’ saved [365164027/365164027]

# %%
import zipfile
with zipfile.ZipFile('data/All-Age-Faces Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('data/aaf/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-63942f954942> in <module>
#       1 import zipfile
#       2 with zipfile.ZipFile('data/All-Age-Faces Dataset.zip', 'r') as zip_ref:
# ----> 3     zip_ref.extractall('data/aaf/')
#
# /anaconda/envs/azureml_py36/lib/python3.6/zipfile.py in extractall(self, path, members, pwd)
#    1522
#    1523         for zipinfo in members:
# -> 1524             self._extract_member(zipinfo, path, pwd)
#    1525
#    1526     @classmethod
#
# /anaconda/envs/azureml_py36/lib/python3.6/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1576
#    1577         with self.open(member, pwd=pwd) as source, \
# -> 1578              open(targetpath, "wb") as target:
#    1579             shutil.copyfileobj(source, target)
#    1580
#
# KeyboardInterrupt:

# %%
fnames = get_image_files('data/aaf/All-Age-Faces Dataset/aglined faces')

# %%
dblock = DataBlock()

# %%
dsets = dblock.datasets(fnames)

# %%
def label_func(fname):
    return int(fname.name[-6:-4])

# %%
dblock = DataBlock( blocks = (ImageBlock, RegressionBlock), 
                    get_items = get_image_files,
                    get_y     = label_func,
                    splitter  = RandomSplitter(),
                    item_tfms = Resize(224))

dsets = dblock.datasets('data/aaf/All-Age-Faces Dataset/aglined faces')
dsets.train[0]
# Out:
# (PILImage mode=RGB size=309x393, tensor(20.))

# %%
dls = dblock.dataloaders(Path('data/aaf/All-Age-Faces Dataset/aglined faces'))

# %%
dls.valid.show_batch(max_n=4, nrows=1)
